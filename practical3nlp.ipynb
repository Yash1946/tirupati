# %%
# =========================================================
# ASSIGNMENT 3
# Text Cleaning, Lemmatization, Stopword Removal,
# Label Encoding and TF-IDF Representation
# =========================================================

# =========================================================
# STEP 1: Import Required Libraries
# =========================================================

import pandas as pd
import re

import nltk

# Download required NLTK resources
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jayra\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\jayra\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jayra\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\jayra\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\jayra\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
# =========================================================
# STEP 2: Create Dataset
# =========================================================

data = {
    "Text": [

        "I love Natural Language Processing.",
        "Machine learning is very interesting.",
        "Deep learning improves AI applications.",
        "NLP helps computers understand human language.",
        "Text analytics is useful in business.",
        "Artificial Intelligence is transforming industries.",
        "Chatbots are becoming more intelligent.",
        "Python is widely used in data science.",
        "This movie was absolutely fantastic.",
        "The product quality is very poor.",
        "I am happy with the service.",
        "The food tasted terrible.",
        "The weather is normal today.",
        "Customer support solved my issue quickly.",
        "The exam was difficult but manageable."

    ],

    "Category": [

        "Positive",
        "Positive",
        "Positive",
        "Positive",
        "Neutral",
        "Neutral",
        "Neutral",
        "Neutral",
        "Positive",
        "Negative",
        "Positive",
        "Negative",
        "Neutral",
        "Positive",
        "Neutral"

    ]
}

df = pd.DataFrame(data)

print("\n==============================")
print("Original Dataset")
print("==============================")

print(df)
# Out:
# ==============================
# Original Dataset
# ==============================
#                                                  Text  Category
# 0                 I love Natural Language Processing.  Positive
# 1               Machine learning is very interesting.  Positive
# 2             Deep learning improves AI applications.  Positive
# 3      NLP helps computers understand human language.  Positive
# 4               Text analytics is useful in business.   Neutral
# 5   Artificial Intelligence is transforming indust...   Neutral
# 6             Chatbots are becoming more intelligent.   Neutral
# 7              Python is widely used in data science.   Neutral
# 8                This movie was absolutely fantastic.  Positive
# 9                   The product quality is very poor.  Negative
# 10                       I am happy with the service.  Positive
# 11                          The food tasted terrible.  Negative
# 12                       The weather is normal today.   Neutral
# 13          Customer support solved my issue quickly.  Positive
# 14             The exam was difficult but manageable.   Neutral

# %%
# =========================================================
# STEP 3: TEXT CLEANING
# =========================================================

print("\n==============================")
print("Text Cleaning")
print("==============================")

# Initialize stopwords and lemmatizer
stop_words = set(stopwords.words('english'))

lemmatizer = WordNetLemmatizer()


# Function for preprocessing text
def preprocess_text(text):

    # Convert to lowercase
    text = text.lower()

    # Remove punctuation and numbers
    text = re.sub(r'[^a-zA-Z\s]', '', text)

    # Tokenization
    tokens = word_tokenize(text)

    # Remove stopwords
    tokens = [word for word in tokens if word not in stop_words]

    # Lemmatization
    tokens = [lemmatizer.lemmatize(word) for word in tokens]

    # Join words back into sentence
    cleaned_text = " ".join(tokens)

    return cleaned_text


# Apply preprocessing
df["Cleaned_Text"] = df["Text"].apply(preprocess_text)

print(df[["Text", "Cleaned_Text"]])
# Out:
# ==============================
# Text Cleaning
# ==============================
#                                                  Text  \
# 0                 I love Natural Language Processing.
# 1               Machine learning is very interesting.
# 2             Deep learning improves AI applications.
# 3      NLP helps computers understand human language.
# 4               Text analytics is useful in business.
# 5   Artificial Intelligence is transforming indust...
# 6             Chatbots are becoming more intelligent.
# 7              Python is widely used in data science.
# 8                This movie was absolutely fantastic.
# 9                   The product quality is very poor.
# 10                       I am happy with the service.
# 11                          The food tasted terrible.
# 12                       The weather is normal today.
# 13          Customer support solved my issue quickly.
# 14             The exam was difficult but manageable.
#
#                                      Cleaned_Text
# 0                love natural language processing
# 1                    machine learning interesting
# 2           deep learning improves ai application
# 3     nlp help computer understand human language
# 4                  text analytics useful business
# 5   artificial intelligence transforming industry
# 6                   chatbots becoming intelligent
# 7                 python widely used data science
# 8                      movie absolutely fantastic
# 9                            product quality poor
# 10                                  happy service
# 11                           food tasted terrible
# 12                           weather normal today
# 13          customer support solved issue quickly
# 14                      exam difficult manageable

# %%
# =========================================================
# STEP 4: LABEL ENCODING
# =========================================================

print("\n==============================")
print("Label Encoding")
print("==============================")

label_encoder = LabelEncoder()

df["Encoded_Label"] = label_encoder.fit_transform(df["Category"])

print(df[["Category", "Encoded_Label"]])
# Out:
# ==============================
# Label Encoding
# ==============================
#     Category  Encoded_Label
# 0   Positive              2
# 1   Positive              2
# 2   Positive              2
# 3   Positive              2
# 4    Neutral              1
# 5    Neutral              1
# 6    Neutral              1
# 7    Neutral              1
# 8   Positive              2
# 9   Negative              0
# 10  Positive              2
# 11  Negative              0
# 12   Neutral              1
# 13  Positive              2
# 14   Neutral              1

# %%
# =========================================================
# STEP 5: TF-IDF REPRESENTATION
# =========================================================

print("\n==============================")
print("TF-IDF Representation")
print("==============================")

tfidf_vectorizer = TfidfVectorizer()

tfidf_matrix = tfidf_vectorizer.fit_transform(df["Cleaned_Text"])

tfidf_df = pd.DataFrame(
    tfidf_matrix.toarray(),
    columns=tfidf_vectorizer.get_feature_names_out()
)

print(tfidf_df)
# Out:
# ==============================
# TF-IDF Representation
# ==============================
#     absolutely        ai  analytics  application  artificial  becoming  \
# 0      0.00000  0.000000        0.0     0.000000         0.0   0.00000
# 1      0.00000  0.000000        0.0     0.000000         0.0   0.00000
# 2      0.00000  0.458638        0.0     0.458638         0.0   0.00000
# 3      0.00000  0.000000        0.0     0.000000         0.0   0.00000
# 4      0.00000  0.000000        0.5     0.000000         0.0   0.00000
# 5      0.00000  0.000000        0.0     0.000000         0.5   0.00000
# 6      0.00000  0.000000        0.0     0.000000         0.0   0.57735
# 7      0.00000  0.000000        0.0     0.000000         0.0   0.00000
# 8      0.57735  0.000000        0.0     0.000000         0.0   0.00000
# 9      0.00000  0.000000        0.0     0.000000         0.0   0.00000
# 10     0.00000  0.000000        0.0     0.000000         0.0   0.00000
# 11     0.00000  0.000000        0.0     0.000000         0.0   0.00000
# 12     0.00000  0.000000        0.0     0.000000         0.0   0.00000
# 13     0.00000  0.000000        0.0     0.000000         0.0   0.00000
# 14     0.00000  0.000000        0.0     0.000000         0.0   0.00000
#
#     business  chatbots  computer  customer  ...   tasted  terrible  text  \
# 0        0.0   0.00000  0.000000  0.000000  ...  0.00000   0.00000   0.0
# 1        0.0   0.00000  0.000000  0.000000  ...  0.00000   0.00000   0.0
# 2        0.0   0.00000  0.000000  0.000000  ...  0.00000   0.00000   0.0
# 3        0.0   0.00000  0.416884  0.000000  ...  0.00000   0.00000   0.0
# 4        0.5   0.00000  0.000000  0.000000  ...  0.00000   0.00000   0.5
# 5        0.0   0.00000  0.000000  0.000000  ...  0.00000   0.00000   0.0
# 6        0.0   0.57735  0.000000  0.000000  ...  0.00000   0.00000   0.0
# 7        0.0   0.00000  0.000000  0.000000  ...  0.00000   0.00000   0.0
# 8        0.0   0.00000  0.000000  0.000000  ...  0.00000   0.00000   0.0
# 9        0.0   0.00000  0.000000  0.000000  ...  0.00000   0.00000   0.0
# 10       0.0   0.00000  0.000000  0.000000  ...  0.00000   0.00000   0.0
# 11       0.0   0.00000  0.000000  0.000000  ...  0.57735   0.57735   0.0
# 12       0.0   0.00000  0.000000  0.000000  ...  0.00000   0.00000   0.0
# 13       0.0   0.00000  0.000000  0.447214  ...  0.00000   0.00000   0.0
# 14       0.0   0.00000  0.000000  0.000000  ...  0.00000   0.00000   0.0
#
#       today  transforming  understand      used  useful  weather    widely
# 0   0.00000           0.0    0.000000  0.000000     0.0  0.00000  0.000000
# 1   0.00000           0.0    0.000000  0.000000     0.0  0.00000  0.000000
# 2   0.00000           0.0    0.000000  0.000000     0.0  0.00000  0.000000
# 3   0.00000           0.0    0.416884  0.000000     0.0  0.00000  0.000000
# 4   0.00000           0.0    0.000000  0.000000     0.5  0.00000  0.000000
# 5   0.00000           0.5    0.000000  0.000000     0.0  0.00000  0.000000
# 6   0.00000           0.0    0.000000  0.000000     0.0  0.00000  0.000000
# 7   0.00000           0.0    0.000000  0.447214     0.0  0.00000  0.447214
# 8   0.00000           0.0    0.000000  0.000000     0.0  0.00000  0.000000
# 9   0.00000           0.0    0.000000  0.000000     0.0  0.00000  0.000000
# 10  0.00000           0.0    0.000000  0.000000     0.0  0.00000  0.000000
# 11  0.00000           0.0    0.000000  0.000000     0.0  0.00000  0.000000
# 12  0.57735           0.0    0.000000  0.000000     0.0  0.57735  0.000000
# 13  0.00000           0.0    0.000000  0.000000     0.0  0.00000  0.000000
# 14  0.00000           0.0    0.000000  0.000000     0.0  0.00000  0.000000
#
# [15 rows x 54 columns]

# %%
# =========================================================
# STEP 6: SAVE OUTPUTS
# =========================================================

print("\n==============================")
print("Saving Outputs")
print("==============================")

# Save processed dataset
df.to_csv("processed_text_data.csv", index=False)

# Save TF-IDF representation
tfidf_df.to_csv("tfidf_output.csv", index=False)

print("Processed dataset saved as: processed_text_data.csv")
print("TF-IDF output saved as: tfidf_output.csv")
# Out:
# ==============================
# Saving Outputs
# ==============================
# Processed dataset saved as: processed_text_data.csv
# TF-IDF output saved as: tfidf_output.csv
